# %% [markdown]
# # Building Image Pairs

# %%
import cv2
import numpy as np
import tensorflow
from keras.datasets import mnist
from imutils import build_montages

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
from google.colab.patches import cv2_imshow

# %%
# image pairs function

def create_image_pair(images_array, images_label):
  labels = np.unique(images_label)
  num_of_labels = len(np.unique(images_label))
  idx = [np.where(images_label == i)[0] for i in range(num_of_labels)]
  pair_images = []
  label_pair = []
  for i in range(len(images_label)):
    current_image = images_array[i]
    current_label = images_label[i]

    # positive pair
    positive_pair_images = np.random.choice(idx[current_label])
    pair_images.append([current_image,images_array[positive_pair_images]])
    label_pair.append([1])
    # negative pair
    negative_pair_images = np.random.choice(idx[np.random.choice(labels[labels != current_label])])
    pair_images.append([current_image,images_array[negative_pair_images]])
    label_pair.append([0])
  
  return (np.array(pair_images), np.array(label_pair))

# %%
pairTrain, labelTrain = create_image_pair(x_train, y_train)
pairTest, labelTest = create_image_pair(x_test, y_test)

# %%
images = []
for i in np.random.choice(np.arange(0, len(pairTrain)), size=(49,)):
	# grab the current image pair and label
	imageA = pairTrain[i][0]
	imageB = pairTrain[i][1]
	label = labelTrain[i]
	# to make it easier to visualize the pairs and their positive or
	# negative annotations, we're going to "pad" the pair with four
	# pixels along the top, bottom, and right borders, respectively
	output = np.zeros((36, 60), dtype="uint8")
	pair = np.hstack([imageA, imageB])
	output[4:32, 0:56] = pair
	# set the text label for the pair along with what color we are
	# going to draw the pair in (green for a "positive" pair and
	# red for a "negative" pair)
	text = "neg" if label[0] == 0 else "pos"
	color = (0, 0, 255) if label[0] == 0 else (0, 255, 0)
	# create a 3-channel RGB image from the grayscale pair, resize
	# it from 60x36 to 96x51 (so we can better see it), and then
	# draw what type of pair it is on the image
	vis = cv2.merge([output] * 3)
	vis = cv2.resize(vis, (96, 51), interpolation=cv2.INTER_LINEAR)
	cv2.putText(vis, text, (2, 12), cv2.FONT_HERSHEY_SIMPLEX, 0.75,
		color, 2)
	# add the pair visualization to our list of output images
	images.append(vis)
 
montage = build_montages(images, (96, 51), (7, 7))[0]
# show the output montage
cv2_imshow(montage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=672x357 at 0x7F943F11A610>
# -1

# %% [markdown]
# ## Triplet Batch

# %%
# image pairs function

def create_image_triplet(images_array, images_label):
  labels = np.unique(images_label)
  num_of_labels = len(np.unique(images_label))
  idx = [np.where(images_label == i)[0] for i in range(num_of_labels)]
  pair_images = []
  label_pair = []
  for i in range(len(images_label)):
    current_image = images_array[i]
    current_label = images_label[i]

    # positive pair
    positive_pair_images = np.random.choice(idx[current_label])
    # negative pair
    negative_pair_images = np.random.choice(idx[np.random.choice(labels[labels != current_label])])
    # Pair append
    pair_images.append([current_image,images_array[positive_pair_images],
                        images_array[negative_pair_images]])
    label_pair.append([1])
  
  return (np.array(pair_images), np.array(label_pair))

# %%
pairTrain, labelTrain = create_image_triplet(x_train, y_train)
pairTest, labelTest = create_image_triplet(x_test, y_test)

# %%
images = []
for i in np.random.choice(np.arange(0, len(pairTrain)), size=(49,)):
	# grab the current image pair and label
    imageA = pairTrain[i][0]
    imageB = pairTrain[i][1]
    imageC = pairTrain[i][2]
    label = labelTrain[i]
    # to make it easier to visualize the pairs and their positive or
    # negative annotations, we're going to "pad" the pair with four
    # pixels along the top, bottom, and right borders, respectively
    output = np.zeros((36, 60), dtype="uint8")
    pair = np.hstack([imageA, imageB])
    output[4:32, 0:56] = pair
    # set the text label for the pair along with what color we are
    # going to draw the pair in (green for a "positive" pair and
    # red for a "negative" pair)
    text = "neg" if label[0] == 0 else "pos"
    color = (0, 0, 255) if label[0] == 0 else (0, 255, 0)
    # create a 3-channel RGB image from the grayscale pair, resize
    # it from 60x36 to 96x51 (so we can better see it), and then
    # draw what type of pair it is on the image
    vis = cv2.merge([output] * 3)
    vis = cv2.resize(vis, (96, 51), interpolation=cv2.INTER_LINEAR)
    cv2.putText(vis, "triplet", (2, 12), cv2.FONT_HERSHEY_SIMPLEX, 0.75,
      color, 2)
    # add the pair visualization to our list of output images
    images.append(vis)
 
montage = build_montages(images, (96, 51), (7, 7))[0]
# show the output montage
cv2_imshow(montage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=672x357 at 0x7F943F119AD0>
# -1

# %% [markdown]
# # Utility Function to compute Distance

# %%
import keras.backend as K

# %%
def euclidean_distance(vectors):
	# unpack the vectors into separate lists
	(featsA, featsB) = vectors
	# compute the sum of squared distances between the vectors
	sumSquared = K.sum(K.square(featsA - featsB), axis=1,
		keepdims=True)
	# return the euclidean distance between the vectors
	return K.sqrt(K.maximum(sumSquared, K.epsilon()))

# %%
import tensorflow as tf
def euclidean_distance_triplets(vectors):
    # unpack the vectors into separate lists
    (featsAnchor, featsPos, featsNeg) = vectors
    ap_distance = tf.reduce_sum(tf.square(featsAnchor - featsPos), -1)
    an_distance = tf.reduce_sum(tf.square(featsAnchor - featsNeg), -1)
    return (ap_distance, an_distance)

# %% [markdown]
# # Building Siamese Network (Sister Network)

# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Lambda, GlobalAveragePooling2D
from keras.models import Model, Input, Sequential
from keras.optimizers import Adam
from keras.metrics import BinaryCrossentropy

# %%
# Feature Extractor model
def build_siamese_model(image_shape, embedding_dim = 48):
  input = Input(shape=image_shape)

  # Perform Convolution and max pooling 1st layer
  x = Conv2D(64, (2,2),padding='same',activation='relu')(input)
  x = MaxPooling2D(pool_size=(2,2))(x)
  x = Dropout(0.2)(x)

  # Perform Convolution and max pooling 2nd layer
  x = Conv2D(64, (2,2),padding='same',activation='relu')(x)
  x = MaxPooling2D(pool_size=(2,2))(x)
  x = Dropout(0.2)(x)
  pooledOutput = GlobalAveragePooling2D()(x)
  output = Dense(embedding_dim)(pooledOutput)
  # Feature Extractor
  model = Model(inputs=input,outputs=output)

  return model

# %% [markdown]
# # Dont run the below code while performing triplet loss

# %%
#Read images
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = np.expand_dims(x_train,axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

pairTrain, labelTrain = create_image_pair(x_train, y_train)
pairTest, labelTest = create_image_pair(x_test, y_test)

# %%
image_shape = (28,28,1)
imgA = Input(image_shape)
imgB = Input(image_shape)
feature_extractor = build_siamese_model(image_shape)
featsA = feature_extractor(imgA)
featsB = feature_extractor(imgB)

# %% [markdown]
# ## Normal Binary Cross Entropy

# %%
distance = Lambda(euclidean_distance)([featsA, featsB])
output = Dense(units=1,activation="sigmoid")(distance)

final_model_binary = Model(inputs = [imgA, imgB], outputs=output)

# %%
final_model_binary.compile(loss="binary_crossentropy", optimizer="adam",metrics=["accuracy"])

# %%
history = final_model_binary.fit(x = [pairTrain[:,0], pairTrain[:,1]],
                          y = labelTrain[:],
                          batch_size = 64,
                          epochs = 30,
                          validation_data = ([pairTest[:,0],pairTest[:,1]], labelTest[:]),
                          )
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.6433 - accuracy: 0.5998 - val_loss: 0.5409 - val_accuracy: 0.7508
# Epoch 2/30
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.5443 - accuracy: 0.7340 - val_loss: 0.4745 - val_accuracy: 0.7895
# Epoch 3/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.4919 - accuracy: 0.7668 - val_loss: 0.4303 - val_accuracy: 0.8098
# Epoch 4/30
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4589 - accuracy: 0.7857 - val_loss: 0.4070 - val_accuracy: 0.8202
# Epoch 5/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.4353 - accuracy: 0.7996 - val_loss: 0.3842 - val_accuracy: 0.8324
# Epoch 6/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.4172 - accuracy: 0.8104 - val_loss: 0.3606 - val_accuracy: 0.8451
# Epoch 7/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.4036 - accuracy: 0.8201 - val_loss: 0.3522 - val_accuracy: 0.8486
# Epoch 8/30
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3956 - accuracy: 0.8252 - val_loss: 0.3351 - val_accuracy: 0.8589
# Epoch 9/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3845 - accuracy: 0.8312 - val_loss: 0.3316 - val_accuracy: 0.8611
# Epoch 10/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3766 - accuracy: 0.8351 - val_loss: 0.3214 - val_accuracy: 0.8641
# Epoch 11/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3672 - accuracy: 0.8390 - val_loss: 0.3154 - val_accuracy: 0.8669
# Epoch 12/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3662 - accuracy: 0.8387 - val_loss: 0.3233 - val_accuracy: 0.8597
# Epoch 13/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3630 - accuracy: 0.8408 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 14/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3529 - accuracy: 0.8470 - val_loss: 0.3086 - val_accuracy: 0.8674
# Epoch 15/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3458 - accuracy: 0.8507 - val_loss: 0.2843 - val_accuracy: 0.8815
# Epoch 16/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3403 - accuracy: 0.8531 - val_loss: 0.2939 - val_accuracy: 0.8738
# Epoch 17/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3397 - accuracy: 0.8535 - val_loss: 0.2865 - val_accuracy: 0.8801
# Epoch 18/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3322 - accuracy: 0.8579 - val_loss: 0.2746 - val_accuracy: 0.8848
# Epoch 19/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3308 - accuracy: 0.8590 - val_loss: 0.2850 - val_accuracy: 0.8785
# Epoch 20/30
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3231 - accuracy: 0.8638 - val_loss: 0.2711 - val_accuracy: 0.8854
# Epoch 21/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3250 - accuracy: 0.8621 - val_loss: 0.2857 - val_accuracy: 0.8788
# Epoch 22/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3232 - accuracy: 0.8621 - val_loss: 0.2725 - val_accuracy: 0.8849
# Epoch 23/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3211 - accuracy: 0.8627 - val_loss: 0.2640 - val_accuracy: 0.8891
# Epoch 24/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3176 - accuracy: 0.8664 - val_loss: 0.2897 - val_accuracy: 0.8740
# Epoch 25/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3184 - accuracy: 0.8644 - val_loss: 0.2668 - val_accuracy: 0.8861
# Epoch 26/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3100 - accuracy: 0.8679 - val_loss: 0.2652 - val_accuracy: 0.8892
# Epoch 27/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3161 - accuracy: 0.8646 - val_loss: 0.2732 - val_accuracy: 0.8834
# Epoch 28/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3133 - accuracy: 0.8670 - val_loss: 0.2570 - val_accuracy: 0.8928
# Epoch 29/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3100 - accuracy: 0.8670 - val_loss: 0.2602 - val_accuracy: 0.8910
# Epoch 30/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3119 - accuracy: 0.8675 - val_loss: 0.2571 - val_accuracy: 0.8928

# %%
final_model_binary.save("model.pb")
# Out:
# INFO:tensorflow:Assets written to: model.pb/assets

# %% [markdown]
# ## Contrastive Loss

# %%
import tensorflow as tf

# %%
def contrastive_loss(y, preds, margin=1):
	y = tf.cast(y, preds.dtype)
	squaredPreds = K.square(preds)
	squaredMargin = K.square(K.maximum(margin - preds, 0))
	loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)
	return loss

# %%
distance = Lambda(euclidean_distance)([featsA, featsB])

final_model = Model(inputs = [imgA, imgB], outputs=distance)

# %%
final_model.compile(loss=contrastive_loss, optimizer="adam")

# %%
history = final_model.fit(x = [pairTrain[:,0], pairTrain[:,1]],
                          y = labelTrain[:],
                          batch_size = 64,
                          epochs = 30,
                          validation_data = ([pairTest[:,0],pairTest[:,1]], labelTest[:]),
                          )
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2694 - val_loss: 0.1169
# Epoch 2/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1333 - val_loss: 0.1100
# Epoch 3/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1266 - val_loss: 0.1106
# Epoch 4/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1239 - val_loss: 0.1080
# Epoch 5/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1215 - val_loss: 0.1056
# Epoch 6/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1208 - val_loss: 0.1046
# Epoch 7/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1204 - val_loss: 0.1030
# Epoch 8/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1197 - val_loss: 0.1016
# Epoch 9/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1199 - val_loss: 0.1049
# Epoch 10/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1192 - val_loss: 0.1003
# Epoch 11/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1187 - val_loss: 0.1048
# Epoch 12/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1191 - val_loss: 0.1022
# Epoch 13/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1182 - val_loss: 0.1045
# Epoch 14/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1181 - val_loss: 0.1016
# Epoch 15/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1174 - val_loss: 0.1006
# Epoch 16/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1177 - val_loss: 0.1042
# Epoch 17/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1185 - val_loss: 0.1009
# Epoch 18/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1182 - val_loss: 0.0994
# Epoch 19/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1176 - val_loss: 0.1035
# Epoch 20/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1178 - val_loss: 0.1025
# Epoch 21/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1170 - val_loss: 0.1048
# Epoch 22/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1171 - val_loss: 0.1029
# Epoch 23/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1169 - val_loss: 0.1011
# Epoch 24/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1167 - val_loss: 0.1002
# Epoch 25/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1162 - val_loss: 0.1006
# Epoch 26/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1171 - val_loss: 0.1004
# Epoch 27/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1173 - val_loss: 0.1020
# Epoch 28/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1159 - val_loss: 0.1025
# Epoch 29/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1165 - val_loss: 0.1029
# Epoch 30/30
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1164 - val_loss: 0.1037

# %% [markdown]
# ## Triplet Loss

# %%
#Read images
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = np.expand_dims(x_train,axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

pairTrain, labelTrain = create_image_triplet(x_train, y_train)
pairTest, labelTest = create_image_triplet(x_test, y_test)

# %%
image_shape = (28,28,1)
anchor = Input(image_shape)
positive = Input(image_shape)
negative = Input(image_shape)
feature_extractor = build_siamese_model(image_shape)
featsAnchor = feature_extractor(anchor)
featsPos = feature_extractor(positive)
featsNeg = feature_extractor(negative)

# %%
#distance = Lambda(euclidean_distance_triplets)([featsAnchor, featsPos, featsNeg])
output = tf.keras.layers.concatenate([featsAnchor, featsPos, featsNeg], axis=1)
final_model_triplet = Model(inputs = [anchor, positive, negative], outputs=output)

# %%
import tensorflow as tf
# def triplet_loss(y, preds, margin=1):
#   print(preds)
#   (anchor_pos_distance, anchor_neg_distance) = preds
#   loss_eqn = anchor_pos_distance - anchor_neg_distance + margin
#   Loss = tf.maximum(loss_eqn,0)
#   return Loss

def triplet_loss(y_true, y_pred, margin = 0.2): 
    emb_size = 48
    anchor, positive, negative = y_pred[:,:emb_size], y_pred[:,emb_size:2*emb_size], y_pred[:,2*emb_size:]
    positive_dist = tf.reduce_mean(tf.square(anchor - positive), axis=1)
    negative_dist = tf.reduce_mean(tf.square(anchor - negative), axis=1)
    return tf.maximum(positive_dist - negative_dist + margin, 0.)

# %%
final_model_triplet.compile(loss=triplet_loss, optimizer="adam")

# %%
history = final_model_triplet.fit(x = [pairTrain[:,0], pairTrain[:,1], pairTrain[:,2]],
                          y = labelTrain[:],
                          batch_size = 64,
                          epochs = 30,
                          validation_data = ([pairTest[:,0],pairTest[:,1],pairTest[:,2]], labelTest[:]),
                          )
# history = final_model_triplet.fit(x = [pairTrain[:,0], pairTrain[:,1], pairTrain[:,2]],
#                           batch_size = 64,
#                           epochs = 30,
#                           )
# Out:
# Epoch 1/30
# 938/938 [==============================] - 44s 12ms/step - loss: 0.1560 - val_loss: 0.1077
# Epoch 2/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.1103 - val_loss: 0.0897
# Epoch 3/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0950 - val_loss: 0.0799
# Epoch 4/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0855 - val_loss: 0.0701
# Epoch 5/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0783 - val_loss: 0.0622
# Epoch 6/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0701 - val_loss: 0.0545
# Epoch 7/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0668 - val_loss: 0.0493
# Epoch 8/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0604 - val_loss: 0.0455
# Epoch 9/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0584 - val_loss: 0.0433
# Epoch 10/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0560 - val_loss: 0.0414
# Epoch 11/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0547 - val_loss: 0.0390
# Epoch 12/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0528 - val_loss: 0.0377
# Epoch 13/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0510 - val_loss: 0.0370
# Epoch 14/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0499 - val_loss: 0.0354
# Epoch 15/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0486 - val_loss: 0.0343
# Epoch 16/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0480 - val_loss: 0.0338
# Epoch 17/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0457 - val_loss: 0.0327
# Epoch 18/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0458 - val_loss: 0.0315
# Epoch 19/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0441 - val_loss: 0.0307
# Epoch 20/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0427 - val_loss: 0.0304
# Epoch 21/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0421 - val_loss: 0.0292
# Epoch 22/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0408 - val_loss: 0.0284
# Epoch 23/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0417 - val_loss: 0.0271
# Epoch 24/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0399 - val_loss: 0.0277
# Epoch 25/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0391 - val_loss: 0.0274
# Epoch 26/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0384 - val_loss: 0.0254
# Epoch 27/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0391 - val_loss: 0.0254
# Epoch 28/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0375 - val_loss: 0.0252
# Epoch 29/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0370 - val_loss: 0.0246
# Epoch 30/30
# 938/938 [==============================] - 11s 11ms/step - loss: 0.0362 - val_loss: 0.0259

# %% [markdown]
# # Using for prediction

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
index = np.random.choice(x_test.shape[0], 10, replace=False)

# %%
for idx_value in index:
  cv2.imwrite(f'{str(idx_value)}.jpeg',x_test[idx_value])

# %% [markdown]
# # Comparing the images using the model built Triplet

# %%
import os
image_list = [dir for dir in os.listdir() if ".jpeg" in dir]

# %%
# randomly select 2 image pairs
test_pairs = np.random.choice(image_list,size = (10,2))

# %%
test_pairs[0]
# Out:
# array(['7921.jpeg', '8122.jpeg'], dtype='<U9')

# %%
import matplotlib.pyplot as plt
y_pred = []
for pair in test_pairs:
    imgA = cv2.imread(pair[0],cv2.IMREAD_GRAYSCALE)
    imgB = cv2.imread(pair[1],cv2.IMREAD_GRAYSCALE)

    orgA = imgA.copy()
    orgB = imgB.copy()

    imgA = np.expand_dims(imgA, axis=-1)
    imgB = np.expand_dims(imgB, axis=-1)

    imgA = np.expand_dims(imgA, axis=0)
    imgB = np.expand_dims(imgB, axis=0)

    imgA = imgA / 255.0
    imgB = imgB / 255.0

    featsA = feature_extractor(imgA)
    featsB = feature_extractor(imgB)
    y_pred = euclidean_distance((imgA, imgB))
    y_pred = y_pred.numpy()[0][0]
    fig = plt.figure("Pair #{}".format(i + 1), figsize=(4, 2))
    plt.suptitle(f"distance: {np.round(y_pred[0][0],2)}")
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(orgA, cmap=plt.cm.gray)
    plt.axis("off")
    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(orgB, cmap=plt.cm.gray)
    plt.axis("off")
    # show the plot
    plt.show()

# %%
val = euclidean_distance((featsA,featsB))

# %%
# Out:
# 3.2603583

# %% [markdown]
# # Comparing the images using the model built

# %%
import os
image_list = [dir for dir in os.listdir() if ".jpeg" in dir]

# %%
# randomly select 2 image pairs
test_pairs = np.random.choice(image_list,size = (10,2))

# %%
import matplotlib.pyplot as plt
y_pred = []
for pair in test_pairs:
    imgA = cv2.imread(pair[0],cv2.IMREAD_GRAYSCALE)
    imgB = cv2.imread(pair[1],cv2.IMREAD_GRAYSCALE)

    orgA = imgA.copy()
    orgB = imgB.copy()

    imgA = np.expand_dims(imgA, axis=-1)
    imgB = np.expand_dims(imgB, axis=-1)

    imgA = np.expand_dims(imgA, axis=0)
    imgB = np.expand_dims(imgB, axis=0)
    
    imgA = imgA / 255.0
    imgB = imgB / 255.0

    y_pred = final_model_binary.predict([imgA, imgB])[0][0]
    fig = plt.figure("Pair #{}".format(i + 1), figsize=(4, 2))
    plt.suptitle("Similarity: {:.2f}".format(y_pred))
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(orgA, cmap=plt.cm.gray)
    plt.axis("off")
    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(orgB, cmap=plt.cm.gray)
    plt.axis("off")
    # show the plot
    plt.show()

# %%
import matplotlib.pyplot as plt
y_pred = []
for pair in test_pairs:
    imgA = cv2.imread(pair[0],cv2.IMREAD_GRAYSCALE)
    imgB = cv2.imread(pair[1],cv2.IMREAD_GRAYSCALE)

    orgA = imgA.copy()
    orgB = imgB.copy()

    imgA = np.expand_dims(imgA, axis=-1)
    imgB = np.expand_dims(imgB, axis=-1)

    imgA = np.expand_dims(imgA, axis=0)
    imgB = np.expand_dims(imgB, axis=0)
    
    imgA = imgA / 255.0
    imgB = imgB / 255.0

    y_pred = final_model.predict([imgA, imgB])[0][0]
    fig = plt.figure("Pair #{}".format(i + 1), figsize=(4, 2))
    plt.suptitle("Distance: {:.2f}".format(y_pred))
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(orgA, cmap=plt.cm.gray)
    plt.axis("off")
    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(orgB, cmap=plt.cm.gray)
    plt.axis("off")
    # show the plot
    plt.show()
